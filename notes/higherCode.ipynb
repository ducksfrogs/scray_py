# %%
import requests

# %%
r = requests.get("http://weather.livedoor.com/forecast/webservice/json/?city=130010")

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_21163/661903446.py in <module>
# ----> 1 r.json()
#
# ~/.bin/anaconda3/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/.bin/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/.bin/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
# ...

# %%
r.text
# Out:
# '\r\r\r\n<!DOCTYPE html>\r\n<html lang="ja">\r\n<head>\r\n<!-- Google Tag Manager -->\r\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-WPKMK2X\');</script>\r\n<!-- End Google Tag Manager -->\r\n<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE9">\r\n<meta charset="utf-8">\r\n<title>livedoor</title>\r\n<meta name="description" content="LINE株式会社が運営するポータルサイト。速報性に加え独自の切り口を誇る「ライブドアニュース」、日本最大のブログサービス「ライブドアブログ」ほか、厳選した情報をお届けします。">\r\n<meta name="keywords" content="ライブドア,ポータル,ニュース,ブログ,livedoor,portal,LINE,LD">\r\n<meta property="og:site_name" content="livedoor">\r\n<meta property="og:image" content="https://image.livedoor.com/img/top/17/livedoor_small.png">\r\n<meta nam
# ...
